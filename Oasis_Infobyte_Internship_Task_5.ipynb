# %% [markdown]
# <a href="https://colab.research.google.com/github/syedameen16/OIBSIP/blob/main/Oasis_Infobyte_Internship_Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/Oasis Infobyte Internship./Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data=data.drop("Unnamed: 0",axis=1)

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=data.iloc[:,0:3]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=data.iloc[:,3]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 134   36.9   38.6       65.6
# 66    31.5   24.6        2.2
# 26   142.9   29.3       12.6
# 113  209.6   20.6       10.7
# 168  215.4   23.6       57.6
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 98   289.7   42.3       51.2
# 177  170.2    7.8       35.2
# 182   56.2    5.7       29.7
# 5      8.7   48.9       75.0
# 146  240.1    7.3        8.7
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 125   87.2   11.8       25.9
# 180  156.6    2.6        8.3
# 154  187.8   21.1        9.5
# 80    76.4   26.7       22.3
# 7    120.2   19.6       11.6
# 33   265.6   20.0        0.3
# 130    0.7   39.6        8.7
# 37    74.7   49.4       45.7
# 74   213.4   24.6       13.1
# 183  287.6   43.0       71.8
# 145  140.3    1.9        9.0
# 45   175.1   22.5       31.5
# 159  131.7   18.4       34.6
# 60    53.5    2.0       21.4
# 123  123.1   34.6       12.4
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 122  224.0    2.4       15.6
# 44    25.1   25.7       43.3
# 16    67.8   36.6      114.0
# ...

# %%
y_train
# Out:
# 134    10.8
# 66      9.5
# 26     15.0
# 113    15.9
# 168    17.1
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107     8.7
# 98     25.4
# 177    11.7
# 182     8.7
# 5       7.2
# 146    13.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    10.5
# 154    15.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     14.9
# 159    12.9
# 60      8.1
# 123    15.2
# 179    12.6
# 185    22.6
# 122    11.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      12.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# Applying Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %% [markdown]
# Evaluvate the performance of a linearregression model

# %%
from sklearn.metrics import mean_squared_error,r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8624865742451985

# %% [markdown]
# Analyze Data by Scatter Plot

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
